# %%
import pandas as pd
import os

# Folder path where all CSVs are stored
data_folder = "data"

# List all CSV files inside the data folder
csv_files = [f for f in os.listdir(data_folder) if f.endswith(".csv")]
print("✅ Found CSV files:", csv_files)

# Load the first CSV file (just to check)
first_file = os.path.join(data_folder, csv_files[0])
df = pd.read_csv(first_file)

# Show first 5 rows
print("\n📊 Preview of first dataset:")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 8
#       5 data_folder = "data"
#       7 # List all CSV files inside the data folder
# ----> 8 csv_files = [f for f in os.listdir(data_folder) if f.endswith(".csv")]
#       9 print("✅ Found CSV files:", csv_files)
#      11 # Load the first CSV file (just to check)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data'

# %%
import os

data_folder = r"C:\Users\HP\projects101\solar-challenge-week0\data"

# List all CSV files in the data folder
csv_files = [f for f in os.listdir(data_folder) if f.endswith(".csv")]
print(csv_files)
# Out:
# ['solar-measurements_zambia-fig-tree_ifc_qc.csv', 'solar-measurements_zambia-mumbwa_ifc_qc.csv', 'solar-measurements_zambia-ndeke_ifc_qc.csv']

# %%
combined_df.isna().sum()
# Out:
# time                         0
# dhi_pyr                   3770
# ghi_pyr_1                  232
# ghi_pyr_2                  232
# air_temperature            233
# relative_humidity          232
# barometric_pressure        232
# precipitation              232
# wind_speed                 232
# wind_from_direction        232
# gti_clean                  232
# gti_soil                   232
# sensor_cleaning            232
# comments               1646469
# dtype: int64
